# %% [markdown]
# <a href="https://colab.research.google.com/github/renato29/datascience/blob/master/aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
uri = "https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula2.1/movies.csv"
pd.read_csv(uri)
# Out:
#       movieId  ...                                       genres
# 0           1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1           2  ...                   Adventure|Children|Fantasy
# 2           3  ...                               Comedy|Romance
# 3           4  ...                         Comedy|Drama|Romance
# 4           5  ...                                       Comedy
# 5           6  ...                        Action|Crime|Thriller
# 6           7  ...                               Comedy|Romance
# 7           8  ...                           Adventure|Children
# 8           9  ...                                       Action
# 9          10  ...                    Action|Adventure|Thriller
# 10         11  ...                         Comedy|Drama|Romance
# 11         12  ...                                Comedy|Horror
# 12         13  ...                 Adventure|Animation|Children
# 13         14  ...                                        Drama
# ...

# %%
filmes = pd.read_csv(uri)
filmes.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
filmes.columns = ["filmesID", "titulo", "generos"]
filmes.head()
# Out:
#    filmesID  ...                                      generos
# 0         1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1         2  ...                   Adventure|Children|Fantasy
# 2         3  ...                               Comedy|Romance
# 3         4  ...                         Comedy|Drama|Romance
# 4         5  ...                                       Comedy
#
# [5 rows x 3 columns]
